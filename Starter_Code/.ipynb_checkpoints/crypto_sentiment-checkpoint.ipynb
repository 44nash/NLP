# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
import json
from pandas.io.json import json_normalize
from token2 import *

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\44nas\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-0d41b48a51d2> in <module>
#       9 import json
#      10 from pandas.io.json import json_normalize
# ---> 11 from token2 import *
#      12
#      13 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'token2'

# %%
# Read your api key environment variable
# YOUR CODE HERE!
from newsapi import NewsApiClient

load_dotenv("api.env")

api_key = os.getenv("news_api")

type(api_key)
# Out:
# 824ea81cd31e42098b2b309b197557a4
# str

# %%
# Create a newsapi client
# YOUR CODE HERE!
newsapi = NewsApiClient(api_key=api_key)
sid = SentimentIntensityAnalyzer()

# %%
def news_dataframe(topic):
    news = newsapi.get_everything(q='{topic}',
                #sources='bbc-news,the-verge',
                language='en',
                sort_by='relevancy')

    
    articles = []
    for article in news['articles']:
        try:
            sentiment = sid.polarity_scores(article["description"])
            title = article["title"]
            description = article["description"]
            text = article["content"]
            date = article["publishedAt"][:10]
            
            articles.append({
                "title": title,
                "description": description,
                "text": text,
                "date": date,
                "compound": sentiment["compound"],
                "positive": sentiment["pos"],
                "negative": sentiment["neg"],
                "neutral": sentiment["neu"],
            })
        except AttributeError:
            pass
    
    return pd.DataFrame(articles)

# %%
# Fetch the Bitcoin news articles
# YOUR CODE HERE!
bitcoin_articles = news_dataframe('bitcoin')

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!
ethereum_articles = news_dataframe('ethereum')

# %%
# Create the Bitcoin sentiment scores DataFrame
# YOUR CODE HERE!
bitcoin_articles.head()
# Out:
#    compound        date                                        description  \
# 0    0.0000  2021-05-18  Prince Harry speaks about mental health in the...
# 1    0.8316  2021-05-28  Hello and welcome back to Equity, TechCrunch’s...
# 2    0.4588  2021-05-19  Hello and welcome back to Equity, TechCrunch’s...
# 3    0.8316  2021-05-24  When I wrote last week about considering wheth...
# 4    0.5267  2021-05-25  It may feel as though we’ve finally said goodb...
#
#    negative  neutral  positive  \
# 0       0.0    1.000     0.000
# 1       0.0    0.791     0.209
# 2       0.0    0.930     0.070
# 3       0.0    0.811     0.189
# 4       0.0    0.888     0.112
#
#                                                 text  \
# 0                   Morning Express with Robin Meade
# 1  Hello and welcome back to Equity, TechCrunchs ...
# 2  Hello and welcome back to Equity, TechCrunchs ...
# 3  When I wrote last week about considering wheth...
# 4  It may feel as though weve finally said goodby...
#
#                                                title
# 0  Prince Harry and Oprah discuss mental health i...
# 1             The SPAC trash ticker is counting down
# 2              What has four wheels and loses money?
# 3  How to Be a More 'Gentle' Parent (and What It ...
# 4  What to Expect From This Year's Hurricane Seas...

# %%
# Create the Ethereum sentiment scores DataFrame
# YOUR CODE HERE!
ethereum_articles.head()
# Out:
#    compound        date                                        description  \
# 0    0.0000  2021-05-18  Prince Harry speaks about mental health in the...
# 1    0.8316  2021-05-28  Hello and welcome back to Equity, TechCrunch’s...
# 2    0.4588  2021-05-19  Hello and welcome back to Equity, TechCrunch’s...
# 3    0.8316  2021-05-24  When I wrote last week about considering wheth...
# 4    0.5267  2021-05-25  It may feel as though we’ve finally said goodb...
#
#    negative  neutral  positive  \
# 0       0.0    1.000     0.000
# 1       0.0    0.791     0.209
# 2       0.0    0.930     0.070
# 3       0.0    0.811     0.189
# 4       0.0    0.888     0.112
#
#                                                 text  \
# 0                   Morning Express with Robin Meade
# 1  Hello and welcome back to Equity, TechCrunchs ...
# 2  Hello and welcome back to Equity, TechCrunchs ...
# 3  When I wrote last week about considering wheth...
# 4  It may feel as though weve finally said goodby...
#
#                                                title
# 0  Prince Harry and Oprah discuss mental health i...
# 1             The SPAC trash ticker is counting down
# 2              What has four wheels and loses money?
# 3  How to Be a More 'Gentle' Parent (and What It ...
# 4  What to Expect From This Year's Hurricane Seas...

# %%
# Describe the Bitcoin Sentiment
# YOUR CODE HERE!
bitcoin_articles.describe()
# Out:
#         compound   negative    neutral   positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.377725   0.029900   0.856100   0.113950
# std     0.417898   0.062849   0.097783   0.096377
# min    -0.476700   0.000000   0.653000   0.000000
# 25%     0.000000   0.000000   0.789500   0.052500
# 50%     0.492750   0.000000   0.858000   0.109000
# 75%     0.690275   0.008500   0.903000   0.150000
# max     0.945100   0.215000   1.000000   0.347000

# %%
bitcoin_articles["description"][0]
# Out:
# 'Prince Harry speaks about mental health in the trailer for an Apple TV+ documentary series with Oprah Winfrey, which aims to destigmatize the topic.'

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!
ethereum_articles.describe()
# Out:
#         compound   negative    neutral   positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.377725   0.029900   0.856100   0.113950
# std     0.417898   0.062849   0.097783   0.096377
# min    -0.476700   0.000000   0.653000   0.000000
# 25%     0.000000   0.000000   0.789500   0.052500
# 50%     0.492750   0.000000   0.858000   0.109000
# 75%     0.690275   0.008500   0.903000   0.150000
# max     0.945100   0.215000   1.000000   0.347000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A:
#
# Q: Which coin had the highest compound score?
#
# A:
#
# Q. Which coin had the highest positive score?
#
# A:

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
# YOUR CODE HERE!
stop_words = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", 
 "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", 
 "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", 
 "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", 
 "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", 
 "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", 
 "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", 
 "between", "into", "through", "during", "before", "after", "above", "below", "to", 
 "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", 
 "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both",
 "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only",
 "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don",
 "should", "now"]

# Expand the default stopwords list if necessary
# YOUR CODE HERE!


# ids = reuters.fileids(categories='gold')
# corpus = [reuters.raw(i) for i in ids]

# %%
# Complete the tokenizer function



# def tokenizer(article):
#    """Tokenizes text."""
#     sw = set(stopwords.words('english'))
#     regex = re.compile("[^a-zA-Z ]")
#     re_clean = regex.sub('', article)
#     words = word_tokenize(re_clean)
#     lem = [lemmatizer.lemmatize(word) for word in words]
#     output = [word.lower() for word in lem if word.lower() not in sw]
#     return tokens

def tokenizer(text):
    
    
#     """Tokenizes text."""
    sw = set(stopwords.words('english'))
    
#   Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
#   Remove the punctuation from text 
    word_tokens = word_tokenize(re_clean)
    
    
#     # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in word_tokens]
   
    filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
    
#     # Remove the stop words
    tokens = [word.lower() for word in lem if word.lower() not in sw]
    
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
# YOUR CODE HERE!
# bitcoin_articles["tokens"] = tokenizer("words sent calm")
article = bitcoin_articles["description"][0]
tokenizer(article)
# Out:
# ['prince',
#  'harry',
#  'speaks',
#  'mental',
#  'health',
#  'trailer',
#  'apple',
#  'tv',
#  'documentary',
#  'series',
#  'oprah',
#  'winfrey',
#  'aim',
#  'destigmatize',
#  'topic']

# %%
# Create a new tokens column for Ethereum
# YOUR CODE HERE!
eth_article = ethereum_articles["description"][0]
tokenizer(eth_article)
# Out:
# ['prince',
#  'harry',
#  'speaks',
#  'mental',
#  'health',
#  'trailer',
#  'apple',
#  'tv',
#  'documentary',
#  'series',
#  'oprah',
#  'winfrey',
#  'aim',
#  'destigmatize',
#  'topic']

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
import nltk, re, string, collections
from collections import Counter
from nltk import ngrams
from nltk.collocations import *
from nltk.util import ngrams
from sklearn.feature_extraction.text import CountVectorizer

# %%
def process_text(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return output

def bigram_counter(corpus): 
    # Combine all articles in corpus into one large string
    big_string = ' '.join(corpus)
    processed = process_text(big_string)
    bigrams = ngrams(processed, n=2)
    top_10 = dict(Counter(bigrams).most_common(10))
    return pd.DataFrame(list(top_10.items()), columns=['bigram', 'count'])

def word_counter(corpus): 
    # Combine all articles in corpus into one large string
    big_string = ' '.join(corpus)
    processed = process_text(big_string)
    top_10 = dict(Counter(processed).most_common(10))
    return pd.DataFrame(list(top_10.items()), columns=['word', 'count'])

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!
corpus = bitcoin_articles["description"]
bigram_counter(corpus)
# Out:
#                       bigram  count
# 0           (hello, welcome)      2
# 1            (welcome, back)      2
# 2           (back, toequity)      2
# 3    (toequity, techcrunchs)      2
# 4     (techcrunchs, venture)      2
# 5  (venture, capitalfocused)      2
# 6  (capitalfocused, podcast)      2
# 7          (podcast, unpack)      2
# 8           (unpack, number)      2
# 9           (number, behind)      2

# %%
# Generate the Ethereum N-grams where N=2
# YOUR CODE HERE!
corpus = ethereum_articles["description"]
bigram_counter(corpus)
# Out:
#                       bigram  count
# 0           (hello, welcome)      2
# 1            (welcome, back)      2
# 2           (back, toequity)      2
# 3    (toequity, techcrunchs)      2
# 4     (techcrunchs, venture)      2
# 5  (venture, capitalfocused)      2
# 6  (capitalfocused, podcast)      2
# 7          (podcast, unpack)      2
# 8           (unpack, number)      2
# 9           (number, behind)      2

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    # Combine all articles in corpus into one large string
    big_string = ' '.join(tokens)
    processed = process_text(big_string)
    top = dict(Counter(processed).most_common(10))
    return pd.DataFrame(list(top.items()), columns=['word', 'count'])

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!
tokens = bitcoin_articles["description"]
token_count(tokens, N=10)
# Out:
#         word  count
# 0      topic      7
# 1       said      5
# 2       time      4
# 3  president      4
# 4    whether      3
# 5      youre      3
# 6       know      3
# 7     speaks      2
# 8         tv      2
# 9      hello      2

# %%
# Use token_count to get the top 10 words for Ethereum
# YOUR CODE HERE!
tokens = ethereum_articles["description"]
token_count(tokens, N=10)
# Out:
#         word  count
# 0      topic      7
# 1       said      5
# 2       time      4
# 3  president      4
# 4    whether      3
# 5      youre      3
# 6       know      3
# 7     speaks      2
# 8         tv      2
# 9      hello      2

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

from nltk.corpus import stopwords
import nltk
import re
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\44nas\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!
corpus = bitcoin_articles["description"]

def process_text(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return ' '.join(output)

big_string = ' '.join(corpus)
input_text = process_text(big_string)

wc = WordCloud().generate(input_text)
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!
corpus = ethereum_articles["description"]

big_string = ' '.join(corpus)
input_text = process_text(big_string)

wc = WordCloud().generate(input_text)
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: en-core-web-sm==3.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl#egg=en_core_web_sm==3.0.0 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (3.0.0)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: setuptools in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (50.3.1.post20201107)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.19.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4; python_version < "3.8" in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.7.4.3)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.5.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.50.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.3)
# Requirement already satisfied: jinja2 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.21.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.4)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.1)
# Requirement already satisfied: six in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.7)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2021.5.30)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: zipp>=0.5; python_version < "3.8" in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from catalogue<2.1.0,>=2.0.3->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.4.0)
# Requirement already satisfied: boto3 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.17.86)
# Requirement already satisfied: botocore<1.21.0,>=1.20.86 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.20.86)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.10.0)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.4.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\44nas\anaconda3\envs\pyvizenv\lib\site-packages (from botocore<1.21.0,>=1.20.86->boto3->smart-open<4.0.0,>=2.2.0->pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.8.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2021-06-18 22:45:26.596837: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-06-18 22:45:26.596864: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# YOUR CODE HERE!
article = bitcoin_articles["description"].str.cat()

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
doc = nlp(article)

# Add a title to the document
# YOUR CODE HERE!
doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prince Harry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  speaks about mental health in the trailer for an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  TV+ documentary series with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oprah Winfrey
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , which aims to destigmatize the topic.Hello and welcome back to Equity, TechCrunch’s venture capital-focused podcast, where we unpack the numbers behind the headlines.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     This week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  had the whole crew aboard to record: Grace and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  making us sound good,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Danny
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to provide levity, Natasha to actually…Hello and welcome back to Equity, TechCrunch’s venture capital-focused podcast, where we unpack the numbers behind the headlines. This is our
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  show, where we niche down to a single topic and go deep. This time
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Natasha
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  corralled TechCrunch tr…When I wrote
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  about considering whether it’s time to change our parenting styles as we emerge from the pandemic,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  reader reached out to ask me if I’d ever heard of gentle parenting. I did not think I had, but it sure sounded nice, so I decided to …It may feel as though we
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ’ve
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  finally said goodbye to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     winter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , but alongside the warmer weather comes hurricane season. In anticipation,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the National Oceanic and Atmospheric Administration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NOAA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) recently released their predictions for the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  hurricane season,…The decision was aimed at the nation’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Catholic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  president and exposed bitter divisions in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American Catholicism
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .If you’re still not ready to leave the house, TV has you covered.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North Korea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will be a key topic when
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em;

# %%
# List all Entities
# YOUR CODE HERE!
print([ent.text for ent in doc.ents if ent.label_ == 'GPE'])
# Out:
# ['North Korea', 'U.S.', 'New York', 'G7', 'New York City']

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!
article = ethereum_articles["description"].str.cat()

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
doc = nlp(article)

# Add a title to the document
# YOUR CODE HERE!
doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prince Harry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  speaks about mental health in the trailer for an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  TV+ documentary series with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oprah Winfrey
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , which aims to destigmatize the topic.Hello and welcome back to Equity, TechCrunch’s venture capital-focused podcast, where we unpack the numbers behind the headlines.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     This week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  had the whole crew aboard to record: Grace and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  making us sound good,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Danny
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to provide levity, Natasha to actually…Hello and welcome back to Equity, TechCrunch’s venture capital-focused podcast, where we unpack the numbers behind the headlines. This is our
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  show, where we niche down to a single topic and go deep. This time
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Natasha
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  corralled TechCrunch tr…When I wrote
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  about considering whether it’s time to change our parenting styles as we emerge from the pandemic,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  reader reached out to ask me if I’d ever heard of gentle parenting. I did not think I had, but it sure sounded nice, so I decided to …It may feel as though we
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ’ve
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  finally said goodbye to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     winter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , but alongside the warmer weather comes hurricane season. In anticipation,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the National Oceanic and Atmospheric Administration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NOAA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) recently released their predictions for the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  hurricane season,…The decision was aimed at the nation’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Catholic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  president and exposed bitter divisions in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American Catholicism
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .If you’re still not ready to leave the house, TV has you covered.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North Korea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will be a key topic when
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em

# %%
# List all Entities
# YOUR CODE HERE!
print([ent.text for ent in doc.ents if ent.label_ == 'GPE'])
# Out:
# ['North Korea', 'U.S.', 'New York', 'G7', 'New York City']

# %% [markdown]
# ---
